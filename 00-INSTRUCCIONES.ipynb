# %% [markdown]
# # 00-INSTRUCCIONES
#
# ### DETECCIÓN DE OPERACIONES DE LAVADO DE ACTIVOS EN ENTIDADES FINANCIERAS
#
# La ejecución de los notebooks de este proyecto debe realizarse siguiendo las siguientes instrucciones:

# %% [markdown]
# ### 1. Lectura de la base de datos
#
# 1.1. La base de datos debe ser descargada de https://www.kaggle.com/x09072993/aml-detection/data y renombrarla como "Tx_bancarias.csv".
#
# 1.2. La base de datos se debe almacenar en la raíz o carpeta en la cual estén almacenadoos los notebooks  01-EDA_operaciones_sospechosas.ipynb y 02-Modelado_evaluacion_op_sospechosas.ipynb.

# %% [markdown]
# ###. 2. Ejecución 01-EDA_operaciones_sospechosas.ipynb
#
# 2.1. El primer notebook a ejecutar es este que se acaba de enunciar y para lo cual se debe garantizar los pasos anteriores.
#
# 2.2. Las líneas de código que se encuentran comentariadas, se pueden ejecutar pero teniendo en cuenta que consumen muchos recursos de máquina y de tiempo, razón por la cual están comentariadas ya que no influyen en el resultado de las otras líneas de código.
#
# 2.3. Al finalizar la ejecución del notebook, este exportará dos bases de datos requeridas para el siguiente notebook: "Data_X.csv" y "Data_Y.csv".
# Estas dos bases de datos no deben ser modificadas o manipuladas ya que son los datos de los atributos de clasificación y el atributo objetivo con las transformaciones aplicadas en este notebook.

# %% [markdown]
# ### 3. Ejecución 02-Modelado_evaluación_op_sospechosas.ipynb
#
# 3.1. Cargar las bases de datos "Data_X.csv" y "Data_Y.csv" en la misma carpeta en la cual se encuentra almacenado este notebook para iniciar su ejecución.
#
# 3.2. Este notebook contiene la ejecución y entrenamiento de los modelos implementados, por lo cual toma más tiempo de ejecución que el anterior. También contiene la final de cada modelo unas líneas comentarias para realizar la validación cruzada del modelo si así se requiere, pero se debe tener en cuenta que consume demasiados recursos de máquina y de tiempo.
#
# 3.3. Este notebook no genera ningún resultado exportable como el anterior y la interpretación de los resultados la puede hacer un experto en ciencia de datos con base a su conocimiento o se puede hacer siguiendo el artículo de Monografía: "Detección de operaciones sospechosas de lavado de activos en entidades financieras, 2022"
#
# Muchas gracias!!
